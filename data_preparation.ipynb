# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import os
import pandas as pd

# %%
pip install opencv-python-headless
# Out:
# ...
#   Using cached opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # data inspection

# %%
import cv2
im = cv2.imread('dataset_highres/images/1165.jpg')
print(im.shape)
# Out:
# (1440, 1080, 3)

# %%
img = mpimg.imread('dataset_highres/images/1163.jpg')
print(im.shape)
imgplot = plt.imshow(img)
plt.show()
# Out:
# (1440, 1080, 3)

# %% [markdown]
# # dataset creation

# %%
image_list = sorted(glob.glob("dataset_highres/images/*")) 
print(len(image_list))
for img in image_list:
    im = cv2.imread(img)
    if im.shape !=  (2400, 1800, 3):     #(80,60,3):
        print(img, im.shape)
# Out:
# 3600
# dataset_highres/images/1163.jpg (1440, 1080, 3)
# dataset_highres/images/1164.jpg (1440, 1080, 3)
# dataset_highres/images/1165.jpg (1440, 1080, 3)
# dataset_highres/images/1526.jpg (1440, 1080, 3)
# dataset_highres/images/1531.jpg (1440, 1080, 3)
# dataset_highres/images/1533.jpg (1440, 1080, 3)
# dataset_highres/images/1536.jpg (1440, 1080, 3)
# dataset_highres/images/1537.jpg (1440, 1080, 3)
# dataset_highres/images/1539.jpg (1440, 1080, 3)
# dataset_highres/images/1540.jpg (1440, 1080, 3)
# dataset_highres/images/1542.jpg (1440, 1080, 3)
# dataset_highres/images/1559.jpg (2401, 1800, 3)
# dataset_highres/images/1562.jpg (1440, 1080, 3)
# dataset_highres/images/1563.jpg (1440, 1080, 3)
# dataset_highres/images/1567.jpg (2401, 1800, 3)
# dataset_highres/images/1569.jpg (1440, 1080, 3)
# dataset_highres/images/1570.jpg (1440, 1080, 3)
# dataset_highres/images/1572.jpg (2400, 1799, 3)
# dataset_highres/images/1573.jpg (1440, 1080, 3)
# ...

# %%
df = pd.read_csv('dataset/styles.csv')

# %%
df.head()
# Out:
#      id  gender masterCategory subCategory articleType baseColour  season  \
# 0  1163     Men        Apparel     Topwear     Tshirts       Blue  Summer
# 1  1164     Men        Apparel     Topwear     Tshirts       Blue  Winter
# 2  1165     Men        Apparel     Topwear     Tshirts       Blue  Summer
# 3  1525  Unisex    Accessories        Bags   Backpacks  Navy Blue    Fall
# 4  1526  Unisex    Accessories        Bags   Backpacks      Black    Fall
#
#      year   usage                                productDisplayName  \
# 0  2011.0  Sports  Nike Sahara Team India Fanwear Round Neck Jersey
# 1  2015.0  Sports           Nike Men Blue T20 Indian Cricket Jersey
# 2  2013.0  Sports               Nike Mean Team India Cricket Jersey
# 3  2010.0  Casual                      Puma Deck Navy Blue Backpack
# 4  2010.0  Sports                       Puma Big Cat Backpack Black
#
#   Unnamed: 10 Unnamed: 11
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# ...

# %%
newdf = pd.DataFrame()
newdf['image_link'] = image_list

# %%
#df[df['id']==6331]['productDisplayName'].iloc[0]
# Out:
# 'UCB Men Ben Logo Yellow Shirt'

# %%
lst = []
for i in image_list:
    image = os.path.basename(i)
    val = int(image[:-4])
    lst.append((df[df['id']==val]['productDisplayName'].iloc[0]))
    

newdf['description'] = lst

# %%
newdf.to_csv('file_highres.csv')
