# %%
# !gsutil help
# Out:
# Usage: gsutil [-D] [-DD] [-h header]... [-i service_account] [-m] [-o section:flag=value]... [-q] [-u user_project] [command [opts...] args...]
# Available commands:
#   acl              Get, set, or change bucket and/or object ACLs
#   autoclass        Configure Autoclass feature
#   bucketpolicyonly Configure uniform bucket-level access
#   cat              Concatenate object content to stdout
#   compose          Concatenate a sequence of objects into a new composite object.
#   config           Obtain credentials and create configuration file
#   cors             Get or set a CORS JSON document for one or more buckets
#   cp               Copy files and objects
#   defacl           Get, set, or change default ACL on buckets
#   defstorageclass  Get or set the default storage class on buckets
#   du               Display object size usage
#   hash             Calculate file hashes
#   help             Get help about commands and topics
# ...

# %%
# !gsutil ls -L -b gs://{higenai-bucket}/
# Out:
# BadRequestException: 400 Invalid bucket name: '{higenai-bucket}'

# %%
# !gsutil ls -L -b gs://higenai-bucket/
# Out:
# gs://higenai-bucket/ :
# 	Storage class:			STANDARD
# 	Location type:			multi-region
# 	Location constraint:		US
# 	Versioning enabled:		None
# 	Logging configuration:		None
# 	Website configuration:		None
# 	CORS configuration: 		None
# 	Lifecycle configuration:	None
# 	Requester Pays enabled:		None
# 	Labels:				None
# 	Default KMS key:		None
# 	Time created:			Mon, 03 Jul 2023 06:26:24 GMT
# 	Time updated:			Mon, 03 Jul 2023 06:26:24 GMT
# 	Metageneration:			1
# 	Bucket Policy Only enabled:	True
# 	Public access prevention:	enforced
# 	RPO:				DEFAULT
# 	ACL:				[]
# 	Default ACL:			[]

# %%
# !gsutil ls -r gs://higenai-bucket/**
# Out:
# gs://higenai-bucket/test/image/1163.jpg
# gs://higenai-bucket/test/image/1164.jpg
# gs://higenai-bucket/test/image/1165.jpg
# gs://higenai-bucket/test/image/1525.jpg
# gs://higenai-bucket/test/image/1526.jpg
# gs://higenai-bucket/test/image/1528.jpg
# gs://higenai-bucket/test/image/1529.jpg
# gs://higenai-bucket/test/image/1530.jpg
# gs://higenai-bucket/test/image/1531.jpg
# gs://higenai-bucket/test/image/1532.jpg
# gs://higenai-bucket/test/image/1533.jpg
# gs://higenai-bucket/test/image/1534.jpg
# gs://higenai-bucket/test/image/1535.jpg
# gs://higenai-bucket/test/image/1536.jpg
# gs://higenai-bucket/test/image/1537.jpg
# gs://higenai-bucket/test/image/1538.jpg
# gs://higenai-bucket/test/image/1539.jpg
# gs://higenai-bucket/test/image/1540.jpg
# gs://higenai-bucket/test/image/1541.jpg
# gs://higenai-bucket/test/image/1542.jpg
# gs://higenai-bucket/test/image/1543.jpg
# gs://higenai-bucket/test/image/1544.jpg
# gs://higenai-bucket/test/image/1545.jpg
# ...

# %%
# !gsutil ls -L -b gs://{higenai-bucket}/
# Out:
# BadRequestException: 400 Invalid bucket name: '{higenai-bucket}'

# %%
# !gsutil ls -L -b gs://higenai-bucket/
# Out:
# gs://higenai-bucket/ :
# 	Storage class:			STANDARD
# 	Location type:			multi-region
# 	Location constraint:		US
# 	Versioning enabled:		None
# 	Logging configuration:		None
# 	Website configuration:		None
# 	CORS configuration: 		None
# 	Lifecycle configuration:	None
# 	Requester Pays enabled:		None
# 	Labels:				None
# 	Default KMS key:		None
# 	Time created:			Mon, 03 Jul 2023 06:26:24 GMT
# 	Time updated:			Mon, 03 Jul 2023 06:26:24 GMT
# 	Metageneration:			1
# 	Bucket Policy Only enabled:	True
# 	Public access prevention:	enforced
# 	RPO:				DEFAULT
# 	ACL:				[]
# 	Default ACL:			[]

# %%
# !gsutil ls -r gs://higenai-bucket/**
# Out:
# gs://higenai-bucket/test/image/1163.jpg
# gs://higenai-bucket/test/image/1164.jpg
# gs://higenai-bucket/test/image/1165.jpg
# gs://higenai-bucket/test/image/1525.jpg
# gs://higenai-bucket/test/image/1526.jpg
# gs://higenai-bucket/test/image/1528.jpg
# gs://higenai-bucket/test/image/1529.jpg
# gs://higenai-bucket/test/image/1530.jpg
# gs://higenai-bucket/test/image/1531.jpg
# gs://higenai-bucket/test/image/1532.jpg
# gs://higenai-bucket/test/image/1533.jpg
# gs://higenai-bucket/test/image/1534.jpg
# gs://higenai-bucket/test/image/1535.jpg
# gs://higenai-bucket/test/image/1536.jpg
# gs://higenai-bucket/test/image/1537.jpg
# gs://higenai-bucket/test/image/1538.jpg
# gs://higenai-bucket/test/image/1539.jpg
# gs://higenai-bucket/test/image/1540.jpg
# gs://higenai-bucket/test/image/1541.jpg
# gs://higenai-bucket/test/image/1542.jpg
# gs://higenai-bucket/test/image/1543.jpg
# gs://higenai-bucket/test/image/1544.jpg
# gs://higenai-bucket/test/image/1545.jpg
# ...

# %%
# !gsutil -m cp gs://higenai-bucket/test/image/* dataset/images/
# Out:
# Copying gs://higenai-bucket/test/image/1163.jpg...
# Copying gs://higenai-bucket/test/image/1164.jpg...
# Copying gs://higenai-bucket/test/image/1165.jpg...
# Copying gs://higenai-bucket/test/image/1525.jpg...
# Copying gs://higenai-bucket/test/image/1526.jpg...
# Copying gs://higenai-bucket/test/image/1528.jpg...
# Copying gs://higenai-bucket/test/image/1529.jpg...
# Copying gs://higenai-bucket/test/image/1530.jpg...
# Copying gs://higenai-bucket/test/image/1531.jpg...
# Copying gs://higenai-bucket/test/image/1533.jpg...
# Copying gs://higenai-bucket/test/image/1534.jpg...
# Copying gs://higenai-bucket/test/image/1532.jpg...
# Copying gs://higenai-bucket/test/image/1535.jpg...
# Copying gs://higenai-bucket/test/image/1537.jpg...
# Copying gs://higenai-bucket/test/image/1536.jpg...
# Copying gs://higenai-bucket/test/image/1548.jpg...
# Copying gs://higenai-bucket/test/image/1538.jpg...
# Copying gs://higenai-bucket/test/image/1544.jpg...
# ...

# %%
# !gsutil ls -r gs://higenai-bucket/test/val/*
# Out:
# gs://higenai-bucket/test/val/8679.jpg
# gs://higenai-bucket/test/val/8680.jpg
# gs://higenai-bucket/test/val/8681.jpg
# gs://higenai-bucket/test/val/8682.jpg
# gs://higenai-bucket/test/val/8683.jpg
# gs://higenai-bucket/test/val/8684.jpg
# gs://higenai-bucket/test/val/8685.jpg
# gs://higenai-bucket/test/val/8686.jpg
# gs://higenai-bucket/test/val/8687.jpg
# gs://higenai-bucket/test/val/8688.jpg

# %%
# !gsutil -m cp gs://higenai-bucket/test/val/* val_images_low/
# Out:
# Copying gs://higenai-bucket/test/val/8679.jpg...
# Copying gs://higenai-bucket/test/val/8680.jpg...
# Copying gs://higenai-bucket/test/val/8681.jpg...
# Copying gs://higenai-bucket/test/val/8682.jpg...
# Copying gs://higenai-bucket/test/val/8684.jpg...
# Copying gs://higenai-bucket/test/val/8685.jpg...
# Copying gs://higenai-bucket/test/val/8686.jpg...
# Copying gs://higenai-bucket/test/val/8687.jpg...
# Copying gs://higenai-bucket/test/val/8683.jpg...
# Copying gs://higenai-bucket/test/val/8688.jpg...
# / [10/10 files][100.1 KiB/100.1 KiB] 100% Done
# Operation completed over 10 objects/100.1 KiB.

# %%
# !gsutil ls -r gs://higenai-bucket/highres/image/*
# Out:
# gs://higenai-bucket/highres/image/1163.jpg
# gs://higenai-bucket/highres/image/1164.jpg
# gs://higenai-bucket/highres/image/1165.jpg
# gs://higenai-bucket/highres/image/1525.jpg
# gs://higenai-bucket/highres/image/1526.jpg
# gs://higenai-bucket/highres/image/1528.jpg
# gs://higenai-bucket/highres/image/1529.jpg
# gs://higenai-bucket/highres/image/1530.jpg
# gs://higenai-bucket/highres/image/1531.jpg
# gs://higenai-bucket/highres/image/1532.jpg
# gs://higenai-bucket/highres/image/1533.jpg
# gs://higenai-bucket/highres/image/1534.jpg
# gs://higenai-bucket/highres/image/1535.jpg
# gs://higenai-bucket/highres/image/1536.jpg
# gs://higenai-bucket/highres/image/1537.jpg
# gs://higenai-bucket/highres/image/1538.jpg
# gs://higenai-bucket/highres/image/1539.jpg
# gs://higenai-bucket/highres/image/1540.jpg
# gs://higenai-bucket/highres/image/1541.jpg
# gs://higenai-bucket/highres/image/1542.jpg
# gs://higenai-bucket/highres/image/1543.jpg
# gs://higenai-bucket/highres/image/1544.jpg
# ...

# %%
# !gsutil -m cp gs://higenai-bucket/highres/image/* dataset_highres/images/
# Out:
# Copying gs://higenai-bucket/highres/image/1163.jpg...
# Copying gs://higenai-bucket/highres/image/1525.jpg...
# Copying gs://higenai-bucket/highres/image/1165.jpg...
# Copying gs://higenai-bucket/highres/image/1526.jpg...
# Copying gs://higenai-bucket/highres/image/1528.jpg...
# Copying gs://higenai-bucket/highres/image/1530.jpg...
# Copying gs://higenai-bucket/highres/image/1531.jpg...
# Copying gs://higenai-bucket/highres/image/1529.jpg...
# Copying gs://higenai-bucket/highres/image/1534.jpg...
# Copying gs://higenai-bucket/highres/image/1164.jpg...
# Copying gs://higenai-bucket/highres/image/1536.jpg...
# Copying gs://higenai-bucket/highres/image/1532.jpg...
# Copying gs://higenai-bucket/highres/image/1539.jpg...
# Copying gs://higenai-bucket/highres/image/1538.jpg...
# Copying gs://higenai-bucket/highres/image/1537.jpg...
# Copying gs://higenai-bucket/highres/image/1535.jpg...
# Copying gs://higenai-bucket/highres/image/1533.jpg...
# ...
